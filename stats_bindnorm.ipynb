# %%
# load relevant packages

import pandas as pd
import ast
import pysam
from Bio import SeqIO
import glob
import math
import numpy as np
from itertools import combinations
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import os
import scipy.stats as stats
from scipy.stats import shapiro
import re

from utils_cb import *
import argparse

# %%
# set up directories to which to point

experiment_id = 'jh_008' # user sets this
desired_metric = 'Mean'
crossreac = 'FHAB'

stats_df_paths = f'data/{experiment_id}/stats/'

csv_files = glob.glob(os.path.join(stats_df_paths, f"*.csv"))
print(csv_files)
# Out:
# ['data/jh_008/stats/2026-01-14_il17scfv_stats.csv']

# %%
stats_df = pd.read_csv(csv_files[0])
# print(stats_df)
stats_important_df = stats_df[['Sample', 'Gate', f'X {desired_metric}', 'Count']].copy()
print(stats_important_df)
# Out:
#            Sample        Gate    X Mean  Count
# 0     y66_120nMAg  All Events    2290.0  50000
# 1     y66_120nMAg          R1     111.0  48452
# 2     y66_120nMAg          R2  393227.0  46054
# 3     y66_120nMAg          R1  416561.0  48452
# 4     y66_120nMAg          R3  275939.0  26677
# ...           ...         ...       ...    ...
# 1435   y85_30nMAg          R5    1167.0    752
# 1436   y85_30nMAg          R3     235.0  24216
# 1437   y85_30nMAg          R3     149.0  24216
# 1438   y85_30nMAg          R7    7710.0     13
# 1439   y85_30nMAg          R3     149.0  24216
#
# [1440 rows x 4 columns]

# %%
sample_list = list(set(stats_important_df['Sample']))
print(len(sample_list))
# Out:
# 60

# %%
samples_dict = {}
cell_name_list = []
ag_conc_list =[]



for sample in sample_list:
    sample_split = sample.split('_')
    if 'ni' not in sample:
        print(sample_split)
        cell_name_list.append(sample_split[0])
        ag_conc_list.append(sample_split[1])
    
        sample_stats_df = stats_important_df[stats_important_df['Sample'] == sample].fillna(0)
        # print(sample_stats_df)
        sample_pivot_df = sample_stats_df.pivot_table(
            index = 'Sample'
            , columns = 'Gate'
            , values = [f'X {desired_metric}', 'Count']
            , aggfunc = 'first'
        )
    
        # print(sample_pivot_df)
    
        # combine {desired_metric} and gate info into a single column
        sample_pivot_df.columns = [f"{val}_{gate}" for val, gate in sample_pivot_df.columns]
    
        quads_gates = ['-/-(1)','-/+(1)','+/-(1)','+/+(1)']
        
        # sample_quad_df = sample_pivot_df[quads_gates].copy()
    
        # print(sample_quad_df)
    
        sample_binding_df = pd.DataFrame()
    
        for gate in quads_gates:
            sample_binding_df[f"{gate}_X{desired_metric}"] = sample_pivot_df[f"X {desired_metric}_{gate}"]
            sample_binding_df[f"{gate}_Count"] = sample_pivot_df[f"Count_{gate}"] 
        
        # sample_quad_df['onbindnorm'] = sample_quad_df['-/+(1)']
        # Compute weighted {desired_metric} fluorescence (onbindnorm) for desired gates
        gates_for_binding = ['+/+(1)', '-/+(1)']
        weighted_sum_bind = sum(sample_binding_df[f"{g}_X{desired_metric}"] * sample_binding_df[f"{g}_Count"] for g in gates_for_binding)
        total_counts_bind = sum(sample_binding_df[f"{g}_Count"] for g in gates_for_binding)
        sample_binding_df['onbindnorm'] = (weighted_sum_bind / total_counts_bind).clip(lower=0)
    
        gates_for_sticky = ['-/-(1)', '+/-(1)']
        weighted_sum_sticky = sum(sample_binding_df[f"{g}_X{desired_metric}"] * sample_binding_df[f"{g}_Count"] for g in gates_for_sticky)
        total_counts_sticky = sum(sample_binding_df[f"{g}_Count"] for g in gates_for_binding)
        sample_binding_df['sticky'] = (weighted_sum_sticky / total_counts_sticky).clip(lower=0)
    
        # Add metadata
        sample_binding_df['Sample'] = sample
        sample_binding_df['cell_name'] = cell_name_list[-1]
        sample_binding_df['concentration_nM'] = ag_conc_list[-1]
    
    
        # # if 'NoAg' in sample:
        # sample_quad_df['onbindnorm'] = sample_quad_df['-/+(1)']
        
        # # sample_quad_df['sticky'] = sample_quad_df['+/-(1)'] / (sample_quad_df['+/-(1)']+sample_quad_df['-/-(1)']+sample_quad_df['-/+(1)'])
        # sample_quad_df['sticky'] = sample_quad_df['-/-(1)'] 
    
        samples_dict[sample] = sample_binding_df
    
# print(samples_dict)
print(list(set(cell_name_list)))
print(list(set(ag_conc_list)))
# Out:
# ['y75', '0nMAg']
# ['y69', '0nMAg']
# ['y83', '120nMAg']
# ['y74', '120nMAg']
# ['y79', '30nMAg']
# ['y75', '30nMAg']
# ['y66', '120nMAg']
# ['y70', '0nMAg']
# ['y78', '30nMAg']
# ['y69', '120nMAg']
# ['y78', '120nMAg']
# ['y76', '0nMAg']
# ['y85', '120nMAg']
# ['y82', '120nMAg']
# ['y78', '0nMAg']
# ['y72', '0nMAg']
# ['y67', '120nMAg']
# ['y71', '120nMAg']
# ['y81', '0nMAg']
# ['y77', '30nMAg']
# ['y67', '0nMAg']
# ['y68', '0nMAg']
# ['y75', '120nMAg']
# ['y84', '30nMAg']
# ['y84', '0nMAg']
# ['y71', '30nMAg']
# ['y77', '120nMAg']
# ['y80', '0nMAg']
# ['y77', '0nMAg']
# ['y74', '0nMAg']
# ['y83', '0nMAg']
# ['y85', '0nMAg']
# ['y67', '30nMAg']
# ['y70', '30nMAg']
# ['y80', '30nMAg']
# ['y66', '0nMAg']
# ['y82', '0nMAg']
# ['y82', '30nMAg']
# ['y81', '30nMAg']
# ['y76', '30nMAg']
# ['y83', '30nMAg']
# ['y72', '120nMAg']
# ['y84', '120nMAg']
# ['y85', '30nMAg']
# ['y81', '120nMAg']
# ['y72', '30nMAg']
# ['y71', '0nMAg']
# ['y73', '120nMAg']
# ['y74', '30nMAg']
# ['y79', '0nMAg']
# ['y68', '30nMAg']
# ['y80', '120nMAg']
# ['y73', '30nMAg']
# ['y68', '120nMAg']
# ['y70', '120nMAg']
# ['y66', '30nMAg']
# ['y79', '120nMAg']
# ['y69', '30nMAg']
# ['y73', '0nMAg']
# ['y76', '120nMAg']
# ['y75', 'y76', 'y81', 'y80', 'y72', 'y78', 'y66', 'y85', 'y82', 'y69', 'y67', 'y84', 'y71', 'y74', 'y77', 'y68', 'y73', 'y79', 'y70', 'y83']
# ['30nMAg', '0nMAg', '120nMAg']

# %%
# print(cell_name_list)
for cellnum in list(set(cell_name_list)):
    print(cellnum)
    cell_keys = [key for key in samples_dict.keys() if cellnum + '_' in key and 'ni' not in key]
    # print(cell_keys)
    
    cell_subset_dict = {key: samples_dict[key] for key in cell_keys if key in samples_dict}
    
    cell_num_df= pd.concat(
        [df.assign(rep_key = key) for key, df in cell_subset_dict.items()],
        ignore_index=True)

    NoAgbind = 0
    
    for conc in cell_num_df['rep_key']:
        if 'NoAg' in conc:
            conc_slice = cell_num_df[cell_num_df['rep_key'] == conc]
            # print(conc_slice)
            NoAgbind = float(conc_slice['onbindnorm'].item() - conc_slice['sticky'].item())
            if NoAgbind < 0:
                NoAgbind = 0
            # print(conc_slice)
    # print(f'NoAg binding correction for yJH{cellnum}: {NoAgbind}')
                
    cell_num_df['correctedbinding'] = cell_num_df['onbindnorm'] - cell_num_df['sticky']


    for idx in range(len(cell_num_df)): # set to 0 if corrected value is negative
        cell_num_df.loc[idx,'cell_name'] = cellnum
        # cell_num_df.loc[idx,'rank_name'] = f'rank {idx}'
        cell_num_df.loc[idx,'concentration'] = cell_num_df.loc[idx,'rep_key'].split('_')[1]
        numbers = ''.join(filter(str.isdigit, cell_num_df.loc[idx,'concentration']))
        cell_num_df.loc[idx,'concentration'] = int(numbers) if numbers else 0
        if cell_num_df.loc[idx,'correctedbinding'] < 0:
            cell_num_df.loc[idx,'correctedbinding'] = 0

    cell_num_df = cell_num_df.sort_values('concentration', ascending = False)

    print(cell_num_df[cell_num_df['correctedbinding'] > 0])
    
    bindcount_df_path = f'data/{experiment_id}/{cellnum}_bindingnorm_{desired_metric}.csv'
    cell_num_df.to_csv(bindcount_df_path)
# Out:
# y75
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y76
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 2          98.0          6293         131.0           150         966.0
# 1          69.0          6377          89.0           245         891.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm       sticky  \
# 2         11561        2729.0          8321  2682.995986  1391.174596
# 1         10699        2465.0          7949  2393.957774  1217.088357
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 2  y76_120nMAg       y76          120nMAg  y76_120nMAg       1291.821391
# 1   y76_30nMAg       y76           30nMAg   y76_30nMAg       1176.869417
#
#   concentration
# 2           120
# 1            30
# y81
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y80
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 2         106.0          7980         118.0           359         919.0
# 1          90.0          9514         127.0           636         590.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm      sticky  \
# 2          6773        2034.0          7569  1947.238648  891.809662
# 1          6133        1412.0          6939  1304.110891  590.723432
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 2  y80_120nMAg       y80          120nMAg  y80_120nMAg       1055.428986
# 1   y80_30nMAg       y80           30nMAg   y80_30nMAg        713.387459
#
#   concentration
# 2           120
# 1            30
# y72
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 1         102.0         14265         145.0           565         499.0
# 2          79.0         11137         128.0           528         459.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm      sticky  \
# 1          4112        1751.0          7842  1643.067325  417.142619
# 2          4429        1369.0          5666  1263.212464  470.250888
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 1  y72_120nMAg       y72          120nMAg  y72_120nMAg       1225.924706
# 2   y72_30nMAg       y72           30nMAg   y72_30nMAg        792.961576
#
#   concentration
# 1           120
# 2            30
# y78
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y66
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 0         112.0          5657         142.0           808        1011.0
# 2          89.0          4863          98.0           802         815.0
# 1          88.0         10673         100.0         16014         451.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm      sticky  \
# 0          4804        5640.0         15408  5366.049334  338.580908
# 2          3755        4759.0         10847  4438.103614  299.865396
# 1           644         344.0          1526   121.228278   70.106499
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 0  y66_120nMAg       y66          120nMAg  y66_120nMAg       5027.468426
# 2   y66_30nMAg       y66           30nMAg   y66_30nMAg       4138.238218
# 1    y66_0nMAg       y66            0nMAg    y66_0nMAg         51.121779
#
#   concentration
# 0           120
# 2            30
# 1             0
# y85
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y82
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 0          99.0         12123         161.0            60        1017.0
# 2          90.0         10939         121.0            76         831.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm       sticky  \
# 0          5419        3760.0          5749  3722.826648  1155.327939
# 2          6454        3015.0          5492  2975.498563  1140.047414
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 0  y82_120nMAg       y82          120nMAg  y82_120nMAg       2567.498709
# 2   y82_30nMAg       y82           30nMAg   y82_30nMAg       1835.451149
#
#   concentration
# 0           120
# 2            30
# y69
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y67
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 0         120.0          8944         167.0            50        1201.0
# 2          92.0          7391         166.0            26        1012.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm       sticky  \
# 0         10582        4938.0          7027  4904.292214  1947.472375
# 2          7254        3576.0          3844  3553.090439  2072.614987
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 0  y67_120nMAg       y67          120nMAg  y67_120nMAg       2956.819839
# 2   y67_30nMAg       y67           30nMAg   y67_30nMAg       1480.475452
#
#   concentration
# 0           120
# 2            30
# y84
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y71
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 0          95.0         11233         158.0          4559         382.0
# 1          65.0         10232         109.0          8385         385.0
# 2          82.0         11292          90.0         13947         373.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count  onbindnorm      sticky  \
# 0          1233         916.0         13051  719.763657   87.344747
# 1          2068         476.0          5715  257.752128  103.635461
# 2          1152         354.0          1837  120.725291   85.886974
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 0  y71_120nMAg       y71          120nMAg  y71_120nMAg        632.418910
# 1   y71_30nMAg       y71           30nMAg   y71_30nMAg        154.116667
# 2    y71_0nMAg       y71            0nMAg    y71_0nMAg         34.838317
#
#   concentration
# 0           120
# 1            30
# 2             0
# y74
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y77
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 1         102.0         15450         140.0          2071         433.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count  onbindnorm      sticky  \
# 1          3822         725.0          5331  561.323291  436.480141
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 1  y77_120nMAg       y77          120nMAg  y77_120nMAg         124.84315
#
#   concentration
# 1           120
# y68
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 2         118.0          8330         152.0           116        1152.0
# 1          94.0          7253         136.0           120        1331.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm       sticky  \
# 2          9617        4215.0         10309  4169.790600  1156.999904
# 1          7021        4196.0          7148  4128.966428  1379.572510
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 2  y68_120nMAg       y68          120nMAg  y68_120nMAg       3012.790695
# 1   y68_30nMAg       y68           30nMAg   y68_30nMAg       2749.393919
#
#   concentration
# 2           120
# 1            30
# y73
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y79
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 2         110.0          8398         134.0           368         744.0
# 0          93.0          9002         122.0           588         595.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm      sticky  \
# 2          6952        1996.0          7839  1912.508347  742.788839
# 0          5707        1388.0          6683  1285.619585  582.155274
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 2  y79_120nMAg       y79          120nMAg  y79_120nMAg       1169.719508
# 0   y79_30nMAg       y79           30nMAg   y79_30nMAg        703.464310
#
#   concentration
# 2           120
# 0            30
# y70
# Empty DataFrame
# Columns: [-/-(1)_XMean, -/-(1)_Count, -/+(1)_XMean, -/+(1)_Count, +/-(1)_XMean, +/-(1)_Count, +/+(1)_XMean, +/+(1)_Count, onbindnorm, sticky, Sample, cell_name, concentration_nM, rep_key, correctedbinding, concentration]
# Index: []
# y83
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 0         113.0         13330         176.0            60         852.0
# 2          91.0         11039         127.0            94         646.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count   onbindnorm       sticky  \
# 0          5169        3384.0          2218  3299.504829  2594.503073
# 2          6607        2995.0          2031  2868.133176  2481.256941
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 0  y83_120nMAg       y83          120nMAg  y83_120nMAg        705.001756
# 2   y83_30nMAg       y83           30nMAg   y83_30nMAg        386.876235
#
#   concentration
# 0           120
# 2            30
