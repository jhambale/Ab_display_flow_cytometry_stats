# %%
# load relevant packages

import pandas as pd
import ast
import pysam
from Bio import SeqIO
import glob
import math
import numpy as np
from itertools import combinations
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import os
from dnds import dnds, pnps
import scipy.stats as stats
from scipy.stats import shapiro
import re

from utils import *
import argparse

# %%
# set up directories to which to point

experiment_id = 'jh_006' # user sets this
desired_metric = 'Mean'

stats_df_paths = f'data/{experiment_id}/stats/'

csv_files = glob.glob(os.path.join(stats_df_paths, f"*.csv"))
print(csv_files)
# Out:
# ['data/jh_006/stats/fhab_AG_251017_stats.csv']

# %%
stats_df = pd.read_csv(csv_files[0])
# print(stats_df)
stats_important_df = stats_df[['Sample', 'Gate', f'X {desired_metric}', 'X Median', 'Count']].copy()
print(stats_important_df)
# Out:
#              Sample        Gate    X Mean  X Median   Count
# 0     r1ni_2000nMAg  All Events       NaN       NaN  110000
# 1     r1ni_2000nMAg          R1      64.0      49.0  108412
# 2     r1ni_2000nMAg          R2  302099.0  252165.0  104980
# 3     r1ni_2000nMAg          R1  312266.0  256581.0  108412
# 4     r1ni_2000nMAg          R3  254654.0  229390.0   85623
# ...             ...         ...       ...       ...     ...
# 1147        r7_NoAg          R5    5187.0    4573.0   53309
# 1148        r7_NoAg          R3    3800.0    3240.0   74050
# 1149        r7_NoAg          R3      74.0      70.0   74050
# 1150        r7_NoAg          R7       NaN       NaN       0
# 1151        r7_NoAg          R3      74.0      70.0   74050
#
# [1152 rows x 5 columns]

# %%
sample_list = list(set(stats_important_df['Sample']))
print(len(sample_list))
# Out:
# 48

# %%
samples_dict = {}
cell_name_list = []
ag_conc_list =[]



for sample in sample_list:
    sample_split = sample.split('_')
    if 'ni' not in sample:
        cell_name_list.append(sample_split[0])
        ag_conc_list.append(sample_split[1])
    
    sample_stats_df = stats_important_df[stats_important_df['Sample'] == sample].fillna(0)
    # print(sample_stats_df)
    sample_pivot_df = sample_stats_df.pivot_table(
        index = 'Sample'
        , columns = 'Gate'
        , values = [f'X {desired_metric}', 'Count']
        , aggfunc = 'first'
    )

    # print(sample_pivot_df)

    # combine {desired_metric} and gate info into a single column
    sample_pivot_df.columns = [f"{val}_{gate}" for val, gate in sample_pivot_df.columns]

    quads_gates = ['-/-(1)','-/+(1)','+/-(1)','+/+(1)']
    
    # sample_quad_df = sample_pivot_df[quads_gates].copy()

    # print(sample_quad_df)

    sample_binding_df = pd.DataFrame()

    for gate in quads_gates:
        sample_binding_df[f"{gate}_X{desired_metric}"] = sample_pivot_df[f"X {desired_metric}_{gate}"]
        sample_binding_df[f"{gate}_Count"] = sample_pivot_df[f"Count_{gate}"] 
    
    # sample_quad_df['onbindnorm'] = sample_quad_df['-/+(1)']
    # Compute weighted {desired_metric} fluorescence (onbindnorm) for desired gates
    gates_for_binding = ['+/+(1)', '-/+(1)']
    weighted_sum_bind = sum(sample_binding_df[f"{g}_X{desired_metric}"] * sample_binding_df[f"{g}_Count"] for g in gates_for_binding)
    total_counts_bind = sum(sample_binding_df[f"{g}_Count"] for g in gates_for_binding)
    sample_binding_df['onbindnorm'] = (weighted_sum_bind / total_counts_bind).clip(lower=0)

    gates_for_sticky = ['-/-(1)', '+/-(1)']
    weighted_sum_sticky = sum(sample_binding_df[f"{g}_X{desired_metric}"] * sample_binding_df[f"{g}_Count"] for g in gates_for_sticky)
    total_counts_sticky = sum(sample_binding_df[f"{g}_Count"] for g in gates_for_binding)
    sample_binding_df['sticky'] = (weighted_sum_sticky / total_counts_sticky).clip(lower=0)

    # Add metadata
    sample_binding_df['Sample'] = sample
    sample_binding_df['cell_name'] = cell_name_list[-1]
    sample_binding_df['concentration_nM'] = ag_conc_list[-1]


    # # if 'NoAg' in sample:
    # sample_quad_df['onbindnorm'] = sample_quad_df['-/+(1)']
    
    # # sample_quad_df['sticky'] = sample_quad_df['+/-(1)'] / (sample_quad_df['+/-(1)']+sample_quad_df['-/-(1)']+sample_quad_df['-/+(1)'])
    # sample_quad_df['sticky'] = sample_quad_df['-/-(1)'] 

    samples_dict[sample] = sample_binding_df
    
# print(samples_dict)
print(list(set(cell_name_list)))
print(list(set(ag_conc_list)))
# Out:
# ['r6', 'r2', 'r4', 'r7', 'r3', 'r1', 'r5']
# ['NoAg', '125nMAg', '31nMAg', '500nMAg', '2000nMAg', '7nMAg']

# %%
# print(cell_name_list)
for cellnum in list(set(cell_name_list)):
    print(cellnum)
    cell_keys = [key for key in samples_dict.keys() if cellnum + '_' in key and 'ni' not in key]
    # print(cell_keys)
    
    cell_subset_dict = {key: samples_dict[key] for key in cell_keys if key in samples_dict}
    
    cell_num_df= pd.concat(
        [df.assign(rep_key = key) for key, df in cell_subset_dict.items()],
        ignore_index=True)

    NoAgbind = 0
    
    for conc in cell_num_df['rep_key']:
        if 'NoAg' in conc:
            conc_slice = cell_num_df[cell_num_df['rep_key'] == conc]
            # print(conc_slice)
            NoAgbind = float(conc_slice['onbindnorm'].item() - conc_slice['sticky'].item())
            if NoAgbind < 0:
                NoAgbind = 0
            # print(conc_slice)
    print(f'NoAg binding correction for yJH{cellnum}: {NoAgbind}')
                
    cell_num_df['correctedbinding'] = cell_num_df['onbindnorm'] - cell_num_df['sticky']


    for idx in range(len(cell_num_df)): # set to 0 if corrected value is negative
        cell_num_df.loc[idx,'cell_name'] = cellnum
        cell_num_df.loc[idx,'concentration'] = cell_num_df.loc[idx,'rep_key'].split('_')[1]
        numbers = ''.join(filter(str.isdigit, cell_num_df.loc[idx,'concentration']))
        cell_num_df.loc[idx,'concentration'] = int(numbers) if numbers else 0
        if cell_num_df.loc[idx,'correctedbinding'] < 0:
            cell_num_df.loc[idx,'correctedbinding'] = 0

    cell_num_df = cell_num_df.sort_values('concentration', ascending = False)

    print(cell_num_df[cell_num_df['correctedbinding'] > 0])
    
    bindcount_df_path = f'data/{experiment_id}/{cellnum}_bindingnorm_{desired_metric}.csv'
    cell_num_df.to_csv(bindcount_df_path)
# Out:
# r6
# NoAg binding correction for yJHr6: 58.1032929420096
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 2          75.0         19124          95.0         50619         952.0
# 4          60.0         19408          78.0         48978        5031.0
# 3          63.0         18799          83.0         49448         463.0
# 0          63.0         19467          81.0         50169         501.0
# 1          63.0         19151          81.0         50623        1854.0
# 5          64.0         19458          81.0         50451         303.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count  onbindnorm     sticky  \
# 2            83         447.0          1635  106.013894  28.960769
# 4           145         918.0          1461  102.331172  37.549813
# 3            47         478.0           973   90.622518  23.920549
# 0            48         462.0           778   86.818164  24.544507
# 1            33         640.0           548   86.986438  24.773700
# 5            20         308.0           385   82.719156  24.615863
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 2  r6_2000nMAg        r6         2000nMAg  r6_2000nMAg         77.053125
# 4   r6_500nMAg        r6          500nMAg   r6_500nMAg         64.781360
# 3   r6_125nMAg        r6          125nMAg   r6_125nMAg         66.701969
# 0    r6_31nMAg        r6           31nMAg    r6_31nMAg         62.273657
# 1     r6_7nMAg        r6            7nMAg     r6_7nMAg         62.212738
# 5      r6_NoAg        r6             NoAg      r6_NoAg         58.103293
#
#   concentration
# 2          2000
# 4           500
# 3           125
# 0            31
# 1             7
# 5             0
# r2
# NoAg binding correction for yJHr2: 57.20458159787958
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 2          68.0         17971          92.0         50125        2346.0
# 3          56.0         20224          74.0         53161         870.0
# 1          56.0         20764          75.0         54227         612.0
# 0          59.0         19814          80.0         52081        1328.0
# 4          56.0         20157          75.0         53032         783.0
# 5          58.0         19246          77.0         52493         324.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count  onbindnorm     sticky  \
# 2           122         541.0          1970  108.979173  28.951723
# 3            89         596.0           934   83.012811  22.367576
# 1            33         538.0           640   80.400696  21.560865
# 0            51         774.0           958   92.535153  23.317823
# 4            14         537.0           330   77.857089  21.358907
# 5            14         307.0           327   78.423892  21.219311
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 2  r2_2000nMAg        r2         2000nMAg  r2_2000nMAg         80.027450
# 3   r2_500nMAg        r2          500nMAg   r2_500nMAg         60.645235
# 1   r2_125nMAg        r2          125nMAg   r2_125nMAg         58.839831
# 0    r2_31nMAg        r2           31nMAg    r2_31nMAg         69.217331
# 4     r2_7nMAg        r2            7nMAg     r2_7nMAg         56.498182
# 5      r2_NoAg        r2             NoAg      r2_NoAg         57.204582
#
#   concentration
# 2          2000
# 3           500
# 1           125
# 0            31
# 4             7
# 5             0
# r4
# NoAg binding correction for yJHr4: 60.42533376618106
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
#
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 4  r3_2000nMAg        r3         2000nMAg  r3_2000nMAg         86.833756
# 3   r3_500nMAg        r3          500nMAg   r3_500nMAg         58.579720
# 1   r3_125nMAg        r3          125nMAg   r3_125nMAg         56.318267
# 5    r3_31nMAg        r3           31nMAg    r3_31nMAg         62.342336
# 2     r3_7nMAg        r3            7nMAg     r3_7nMAg         56.598488
# 0      r3_NoAg        r3             NoAg      r3_NoAg         60.905019
#
#   concentration
# 4          2000
# 3           500
# 1           125
# 5            31
# 2             7
# 0             0
# r1
# NoAg binding correction for yJHr1: 60.34704589118422
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 4          56.0         20750          74.0         50219        1446.0
# 2          59.0         19822          76.0         50413        1783.0
# 1          58.0         19870          76.0         51072         684.0
# 0          59.0         18388          77.0         48152        1034.0
# 3          60.0         18824          79.0         50699        2559.0
# 5          62.0         18446          81.0         50039         293.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count  onbindnorm     sticky  \
# 4           213         978.0          2116  110.550377  28.088239
# 2           114         633.0          1032   87.173564  26.684031
# 1            50         377.0           556   79.241574  22.984814
# 0            36         499.0           519   81.499969  23.055125
# 3            23         581.0           440   83.319208  23.236610
# 5            15         315.0           450   83.085603  22.738557
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 4  r1_2000nMAg        r1         2000nMAg  r1_2000nMAg         82.462138
# 2   r1_500nMAg        r1          500nMAg   r1_500nMAg         60.489533
# 1   r1_125nMAg        r1          125nMAg   r1_125nMAg         56.256760
# 0    r1_31nMAg        r1           31nMAg    r1_31nMAg         58.444844
# 3     r1_7nMAg        r1            7nMAg     r1_7nMAg         60.082598
# 5      r1_NoAg        r1             NoAg      r1_NoAg         60.347046
#
#   concentration
# 4          2000
# 2           500
# 1           125
# 0            31
# 3             7
# 5             0
# r5
# NoAg binding correction for yJHr5: 58.37704421562689
#    -/-(1)_XMean  -/-(1)_Count  -/+(1)_XMean  -/+(1)_Count  +/-(1)_XMean  \
# 1          77.0         18983          99.0         48283         499.0
# 3          62.0         18844          80.0         48690         535.0
# 2          63.0         17880          80.0         45982         851.0
# 0          65.0         17698          84.0         47885        1035.0
# 5          63.0         17571          82.0         47523         315.0
# 4          64.0         18823          81.0         49137         292.0
#
#    +/-(1)_Count  +/+(1)_XMean  +/+(1)_Count  onbindnorm     sticky  \
# 1           186         485.0          2455  117.676929  30.637885
# 3            94         609.0          1061   91.281562  24.494342
# 2            37         448.0           656   85.176208  24.827973
# 0            37         332.0           793   88.040100  24.418937
# 5            16         326.0           469   84.384481  23.170799
# 4            20         310.0           393   82.817020  24.439976
#
#         Sample cell_name concentration_nM      rep_key  correctedbinding  \
# 1  r5_2000nMAg        r5         2000nMAg  r5_2000nMAg         87.039044
# 3   r5_500nMAg        r5          500nMAg   r5_500nMAg         66.787220
# 2   r5_125nMAg        r5          125nMAg   r5_125nMAg         60.348235
# 0    r5_31nMAg        r5           31nMAg    r5_31nMAg         63.621164
# 5     r5_7nMAg        r5            7nMAg     r5_7nMAg         61.213681
# 4      r5_NoAg        r5             NoAg      r5_NoAg         58.377044
#
#   concentration
# 1          2000
# 3           500
# 2           125
# 0            31
# 5             7
# 4             0
