# %%
# load relevant packages

import pandas as pd
import ast
import pysam
from Bio import SeqIO
import glob
import math
import numpy as np
from itertools import combinations
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import os
from dnds import dnds, pnps
import scipy.stats as stats
from scipy.stats import shapiro
import re

from utils import *
import argparse

# %%
# set up directories to which to point

experiment_id = 'jh_006' # user sets this

stats_df_paths = f'data/{experiment_id}/stats/'

csv_files = glob.glob(os.path.join(stats_df_paths, f"*.csv"))
print(csv_files)
# Out:
# ['data/jh_006/stats/fhab_AG_251017_stats.csv']

# %%
stats_df = pd.read_csv(csv_files[0])
# print(stats_df)
stats_important_df = stats_df[['Sample', 'Gate', 'X Mean', 'X Median']].copy()
print(stats_important_df)
# Out:
#              Sample        Gate    X Mean  X Median
# 0     r1ni_2000nMAg  All Events       NaN       NaN
# 1     r1ni_2000nMAg          R1      64.0      49.0
# 2     r1ni_2000nMAg          R2  302099.0  252165.0
# 3     r1ni_2000nMAg          R1  312266.0  256581.0
# 4     r1ni_2000nMAg          R3  254654.0  229390.0
# ...             ...         ...       ...       ...
# 1147        r7_NoAg          R5    5187.0    4573.0
# 1148        r7_NoAg          R3    3800.0    3240.0
# 1149        r7_NoAg          R3      74.0      70.0
# 1150        r7_NoAg          R7       NaN       NaN
# 1151        r7_NoAg          R3      74.0      70.0
#
# [1152 rows x 4 columns]

# %%
sample_list = list(set(stats_important_df['Sample']))
print(len(sample_list))
# Out:
# 48

# %%
samples_dict = {}
cell_name_list = []
ag_conc_list =[]

desired_metric = 'Mean'

for sample in sample_list:
    sample_split = sample.split('_')
    if 'ni' not in sample:
        cell_name_list.append(sample_split[0])
        ag_conc_list.append(sample_split[1])
    
    sample_stats_df = stats_important_df[stats_important_df['Sample'] == sample].fillna(0)
    # print(sample_stats_df)
    sample_pivot_df = sample_stats_df.pivot_table(
        index = 'Sample'
        , columns = 'Gate'
        , values = f'X {desired_metric}'
        , aggfunc = 'first'
    )

    # print(sample_pivot_df)

    quads_gates = ['-/-(1)','-/+(1)','+/-(1)','+/+(1)']
    
    sample_quad_df = sample_pivot_df[quads_gates].copy()

    # print(sample_quad_df)
    
    sample_quad_df['onbindnorm'] = sample_quad_df['-/+(1)']

    if 'NoAg' in sample:
        sample_quad_df['onbindnorm'] = sample_quad_df['-/+(1)']
    
    # sample_quad_df['sticky'] = sample_quad_df['+/-(1)'] / (sample_quad_df['+/-(1)']+sample_quad_df['-/-(1)']+sample_quad_df['-/+(1)'])
    sample_quad_df['sticky'] = sample_quad_df['-/-(1)'] 

    samples_dict[sample] = sample_quad_df
    
# print(samples_dict)
print(list(set(cell_name_list)))
print(list(set(ag_conc_list)))
# Out:
# ['r5', 'r3', 'r4', 'r2', 'r7', 'r6', 'r1']
# ['2000nMAg', '500nMAg', '125nMAg', '7nMAg', '31nMAg', 'NoAg']

# %%
# print(cell_name_list)
for cellnum in list(set(cell_name_list)):
    print(cellnum)
    cell_keys = [key for key in samples_dict.keys() if cellnum + '_' in key and 'ni' not in key]
    # print(cell_keys)
    
    cell_subset_dict = {key: samples_dict[key] for key in cell_keys if key in samples_dict}
    
    cell_num_df= pd.concat(
        [df.assign(rep_key = key) for key, df in cell_subset_dict.items()],
        ignore_index=True)

    NoAgbind = 0
    
    for conc in cell_num_df['rep_key']:
        if 'NoAg' in conc:
            conc_slice = cell_num_df[cell_num_df['rep_key'] == conc]
            # print(conc_slice)
            NoAgbind = float(conc_slice['onbindnorm'].item() - conc_slice['sticky'].item())
            if NoAgbind < 0:
                NoAgbind = 0
            # print(conc_slice)
    print(f'NoAg binding correction for yJH{cellnum}: {NoAgbind}')
                
    cell_num_df['correctedbinding'] = cell_num_df['onbindnorm'] - cell_num_df['sticky']


    for idx in range(len(cell_num_df)): # set to 0 if corrected value is negative
        cell_num_df.loc[idx,'cell_name'] = 'yJH'+cellnum
        cell_num_df.loc[idx,'concentration'] = cell_num_df.loc[idx,'rep_key'].split('_')[1]
        numbers = ''.join(filter(str.isdigit, cell_num_df.loc[idx,'concentration']))
        cell_num_df.loc[idx,'concentration'] = int(numbers) if numbers else 0
        if cell_num_df.loc[idx,'correctedbinding'] < 0:
            cell_num_df.loc[idx,'correctedbinding'] = 0

    cell_num_df = cell_num_df.sort_values('concentration', ascending = False)

    print(cell_num_df[cell_num_df['correctedbinding'] > 0])
    
    bindcount_df_path = f'data/{experiment_id}/{cellnum}_bindingnorm_{desired_metric}.csv'
    cell_num_df.to_csv(bindcount_df_path)
# Out:
# r5
# NoAg binding correction for yJHr5: 17.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 2       77.0    99.0   499.0   485.0        99.0    77.0  r5_2000nMAg
# 5       62.0    80.0   535.0   609.0        80.0    62.0   r5_500nMAg
# 0       63.0    80.0   851.0   448.0        80.0    63.0   r5_125nMAg
# 3       65.0    84.0  1035.0   332.0        84.0    65.0    r5_31nMAg
# 1       63.0    82.0   315.0   326.0        82.0    63.0     r5_7nMAg
# 4       64.0    81.0   292.0   310.0        81.0    64.0      r5_NoAg
#
# Gate  correctedbinding cell_name concentration
# 2                 22.0     yJHr5          2000
# 5                 18.0     yJHr5           500
# 0                 17.0     yJHr5           125
# 3                 19.0     yJHr5            31
# 1                 19.0     yJHr5             7
# 4                 17.0     yJHr5             0
# r3
# NoAg binding correction for yJHr3: 19.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 2       72.0    97.0  1767.0   636.0        97.0    72.0  r3_2000nMAg
# 0       59.0    76.0  2468.0   665.0        76.0    59.0   r3_500nMAg
# 3       60.0    78.0  5843.0   448.0        78.0    60.0   r3_125nMAg
# 4       61.0    81.0   312.0   343.0        81.0    61.0    r3_31nMAg
# 5       60.0    78.0  1587.0   331.0        78.0    60.0     r3_7nMAg
# 1       62.0    81.0   334.0   353.0        81.0    62.0      r3_NoAg
#
# Gate  correctedbinding cell_name concentration
# 2                 25.0     yJHr3          2000
# 0                 17.0     yJHr3           500
# 3                 18.0     yJHr3           125
# 4                 20.0     yJHr3            31
# 5                 18.0     yJHr3             7
# 1                 19.0     yJHr3             0
# r4
# NoAg binding correction for yJHr4: 20.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 4       71.0    94.0   871.0   528.0        94.0    71.0  r4_2000nMAg
# 3       60.0    78.0   903.0   743.0        78.0    60.0   r4_500nMAg
# 5       58.0    77.0   716.0   461.0        77.0    58.0   r4_125nMAg
# 0       61.0    81.0   554.0   357.0        81.0    61.0    r4_31nMAg
# 1       60.0    81.0   372.0   326.0        81.0    60.0     r4_7nMAg
# 2       61.0    81.0   294.0   358.0        81.0    61.0      r4_NoAg
#
# Gate  correctedbinding cell_name concentration
# 4                 23.0     yJHr4          2000
# 3                 18.0     yJHr4           500
# 5                 19.0     yJHr4           125
# 0                 20.0     yJHr4            31
# 1                 21.0     yJHr4             7
# 2                 20.0     yJHr4             0
# r2
# NoAg binding correction for yJHr2: 19.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 0       68.0    92.0  2346.0   541.0        92.0    68.0  r2_2000nMAg
# 2       56.0    74.0   870.0   596.0        74.0    56.0   r2_500nMAg
# 4       56.0    75.0   612.0   538.0        75.0    56.0   r2_125nMAg
# 5       59.0    80.0  1328.0   774.0        80.0    59.0    r2_31nMAg
# 3       56.0    75.0   783.0   537.0        75.0    56.0     r2_7nMAg
# 1       58.0    77.0   324.0   307.0        77.0    58.0      r2_NoAg
#
# Gate  correctedbinding cell_name concentration
# 0                 24.0     yJHr2          2000
# 2                 18.0     yJHr2           500
# 4                 19.0     yJHr2           125
# 5                 21.0     yJHr2            31
# 3                 19.0     yJHr2             7
# 1                 19.0     yJHr2             0
# r7
# NoAg binding correction for yJHr7: 16.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 4       72.0    91.0  1026.0   535.0        91.0    72.0  r7_2000nMAg
# 5       61.0    77.0  2753.0   501.0        77.0    61.0   r7_500nMAg
# 0       59.0    74.0  3397.0   391.0        74.0    59.0   r7_125nMAg
# 1       62.0    78.0   482.0   351.0        78.0    62.0    r7_31nMAg
# 3       62.0    80.0   400.0   313.0        80.0    62.0     r7_7nMAg
# 2       61.0    77.0   303.0   308.0        77.0    61.0      r7_NoAg
#
# Gate  correctedbinding cell_name concentration
# 4                 19.0     yJHr7          2000
# 5                 16.0     yJHr7           500
# 0                 15.0     yJHr7           125
# 1                 16.0     yJHr7            31
# 3                 18.0     yJHr7             7
# 2                 16.0     yJHr7             0
# r6
# NoAg binding correction for yJHr6: 17.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 1       75.0    95.0   952.0   447.0        95.0    75.0  r6_2000nMAg
# 4       60.0    78.0  5031.0   918.0        78.0    60.0   r6_500nMAg
# 0       63.0    83.0   463.0   478.0        83.0    63.0   r6_125nMAg
# 2       63.0    81.0   501.0   462.0        81.0    63.0    r6_31nMAg
# 3       63.0    81.0  1854.0   640.0        81.0    63.0     r6_7nMAg
# 5       64.0    81.0   303.0   308.0        81.0    64.0      r6_NoAg
#
# Gate  correctedbinding cell_name concentration
# 1                 20.0     yJHr6          2000
# 4                 18.0     yJHr6           500
# 0                 20.0     yJHr6           125
# 2                 18.0     yJHr6            31
# 3                 18.0     yJHr6             7
# 5                 17.0     yJHr6             0
# r1
# NoAg binding correction for yJHr1: 19.0
# Gate  -/-(1)  -/+(1)  +/-(1)  +/+(1)  onbindnorm  sticky      rep_key  \
# 3       56.0    74.0  1446.0   978.0        74.0    56.0  r1_2000nMAg
# 1       59.0    76.0  1783.0   633.0        76.0    59.0   r1_500nMAg
# 4       58.0    76.0   684.0   377.0        76.0    58.0   r1_125nMAg
# 5       59.0    77.0  1034.0   499.0        77.0    59.0    r1_31nMAg
# 2       60.0    79.0  2559.0   581.0        79.0    60.0     r1_7nMAg
# 0       62.0    81.0   293.0   315.0        81.0    62.0      r1_NoAg
#
# Gate  correctedbinding cell_name concentration
# 3                 18.0     yJHr1          2000
# 1                 17.0     yJHr1           500
# 4                 18.0     yJHr1           125
# 5                 18.0     yJHr1            31
# 2                 19.0     yJHr1             7
# 0                 19.0     yJHr1             0
